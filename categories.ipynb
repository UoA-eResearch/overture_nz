# %%
import pandas as pd
df = pd.read_csv("overture_NZ.csv")
df
# Out:
#                                        name                     main_category  \
# 0                              Pearl Island  landmark_and_historical_building
# 1                              Kopeka River                             river
# 2                              Toitoi River                             river
# 3                               Lords River                             river
# 4                            Rakeahua River                             river
# ...                                     ...                               ...
# 136268                         Waikahoa Bay                             beach
# 136269                        Motutara Farm                        campground
# 136270             Whananaki North Doc Camp                        campground
# 136271                Otamure Bay Camp Site                        campground
# 136272  Poor Knights Islands Marine Reserve                     national_park
#
#                       alternate_categories        lat         lng
# 0                          island,monument -47.189700  167.706000
# 1                                      NaN -47.133333  167.933333
# 2                                      NaN -47.116667  167.983333
# 3                                      NaN -47.116667  168.150000
# 4                                      NaN -46.983333  167.900000
# ...                                    ...        ...         ...
# 136268  structure_and_geography,campground -35.442454  174.412243
# 136269                          farm,hotel -35.505100  174.467260
# 136270                                 NaN -35.501872  174.468942
# 136271       beach,structure_and_geography -35.491895  174.462971
# 136272                   water_park,island -35.481378  174.737203
#
# [136273 rows x 5 columns]

# %%
df.main_category.value_counts().head(50)
# Out:
# main_category
# beauty_salon                        5131
# cafe                                3606
# hotel                               3420
# community_services_non_profits      2651
# park                                2593
# automotive_repair                   2427
# real_estate_agent                   1876
# shopping                            1803
# gym                                 1801
# church_cathedral                    1691
# school                              1690
# sports_club_and_league              1542
# professional_services               1508
# coffee_shop                         1448
# landmark_and_historical_building    1435
# bar                                 1365
# real_estate                         1294
# beach                               1206
# flowers_and_gifts_shop              1201
# grocery_store                       1196
# spas                                1182
# preschool                           1163
# restaurant                          1072
# river                               1049
# bakery                              1026
# active_life                         1022
# hospital                             962
# car_dealer                           954
# liquor_store                         927
# gas_station                          923
# clothing_store                       869
# fast_food_restaurant                 824
# dentist                              815
# bed_and_breakfast                    793
# pharmacy                             793
# indian_restaurant                    763
# engineering_services                 739
# art_gallery                          736
# education                            733
# elementary_school                    695
# farm                                 688
# women's_clothing_store               670
# furniture_store                      658
# martial_arts_club                    658
# barber                               657
# pizza_restaurant                     647
# naturopathic_holistic                643
# religious_organization               640
# college_university                   624
# shipping_center                      610
# Name: count, dtype: int64

# %%
# Add top level category from taxonomy
overture_taxonomy = pd.read_csv("https://raw.githubusercontent.com/OvertureMaps/schema/main/task-force-docs/places/overture_categories.csv", sep=";")
overture_taxonomy["Overture Taxonomy"] = overture_taxonomy["Overture Taxonomy"].apply(lambda s: s.strip("[]").split(","))
overture_taxonomy.set_index("Category code", inplace=True)
overture_taxonomy = overture_taxonomy["Overture Taxonomy"]
df["top_level_category"] = df.main_category.apply(lambda c: overture_taxonomy.get(c, [None])[0])
df
# Out:
#                                        name                     main_category  \
# 0                              Pearl Island  landmark_and_historical_building
# 1                              Kopeka River                             river
# 2                              Toitoi River                             river
# 3                               Lords River                             river
# 4                            Rakeahua River                             river
# ...                                     ...                               ...
# 136268                         Waikahoa Bay                             beach
# 136269                        Motutara Farm                        campground
# 136270             Whananaki North Doc Camp                        campground
# 136271                Otamure Bay Camp Site                        campground
# 136272  Poor Knights Islands Marine Reserve                     national_park
#
#                       alternate_categories        lat         lng  \
# 0                          island,monument -47.189700  167.706000
# 1                                      NaN -47.133333  167.933333
# 2                                      NaN -47.116667  167.983333
# 3                                      NaN -47.116667  168.150000
# 4                                      NaN -46.983333  167.900000
# ...                                    ...        ...         ...
# 136268  structure_and_geography,campground -35.442454  174.412243
# 136269                          farm,hotel -35.505100  174.467260
# 136270                                 NaN -35.501872  174.468942
# 136271       beach,structure_and_geography -35.491895  174.462971
# 136272                   water_park,island -35.481378  174.737203
#
#                 top_level_category
# 0       attractions_and_activities
# 1          structure_and_geography
# 2          structure_and_geography
# 3          structure_and_geography
# 4          structure_and_geography
# ...                            ...
# 136268  attractions_and_activities
# 136269               accommodation
# 136270               accommodation
# 136271               accommodation
# 136272  attractions_and_activities
#
# [136273 rows x 6 columns]

# %%
df.top_level_category.value_counts()
# Out:
# top_level_category
# retail                                   23787
# eat_and_drink                            16199
# professional_services                     9394
# active_life                               8602
# attractions_and_activities                8338
# beauty_and_spa                            8149
# automotive                                7390
# accommodation                             6535
# education                                 6344
# health_and_medical                        6012
# public_service_and_government             5946
# business_to_business                      4309
# real_estate                               4186
# home_service                              3073
# arts_and_entertainment                    3032
# religious_organization                    2981
# travel                                    2606
# financial_service                         2020
# structure_and_geography                   1823
# pets                                      1364
# mass_media                                 431
# private_establishments_and_corporates       56
# Name: count, dtype: int64
